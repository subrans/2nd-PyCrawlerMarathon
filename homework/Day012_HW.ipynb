# %% [markdown]
# # Ettoday 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 取出今天所有的發文
# * ② 如果想要依照類別分類，怎麼儲存會比較好？
# * ③ 哪一個類別的文章最多

# %% [markdown]
# ### ① 取出今天所有的發文

# %%
'''
Your Code
'''
import requests
from bs4 import BeautifulSoup

url = 'https://www.ettoday.net/news/news-list.htm'
r = requests.get(url)

soup = BeautifulSoup(r.text, "html5lib")
#print(soup)
for d in soup.find(class_="part_list_2").find_all('h3'):
    #print(d.find(class_="date").text, d.find(class_="tag c_travel").text, d.find_all('a')[-1].text)
    print(d.find(class_="date").text, d.find(target="_blank").text)
# Out:
# 2020/03/05 16:01 死忠基迷如願加盟洋基　他養的狗就叫「基特」
# 2020/03/05 16:01 手機品牌保持大比拚！iPhone海放Android旗艦機
# 2020/03/05 16:00 新北未取消酒測　以「目視、酒味」判斷為主
# 2020/03/05 15:59 控法官「男盜女娼」收賄美金40萬元　老營造商返台「我要面對」結果被起訴
# 2020/03/05 15:57 高虹安用大數據找出缺口罩地點　陳時中：教教我們
# 2020/03/05 15:57 原來這些星座是另一半最想留住的幸運！包容力超高的情人TOP 4別輕易放手
# 2020/03/05 15:55 「疫」起迎轉機
# 2020/03/05 15:55 怎麼有效學習拿高分？專家給解答：讀書如同記住「遊戲規則」
# 2020/03/05 15:54 整理櫃子卻翻到「土豪級口罩」！她嗨喊「這大概100萬吧」…網笑：一夜致富
# 2020/03/05 15:52 高速公路攔車抓人！改槍工廠曝光　主嫌找車工鑽槍管販售
# 2020/03/05 15:51 王鴻薇批游錫堃「高調耍官威」　要求向警察道歉
# 2020/03/05 15:51 首入選全球最佳新興智庫　國防院：澎湖軍事戰略地位已超金馬
# 2020/03/05 15:50 疫情擴大世界各地監獄均淪陷！我國矯正機關防疫引為借鑑
# 2020/03/05 15:50 兩岸交火金馬需「獨立防衛」　國防院：以利本島戰力保存
# 2020/03/05 15:48 揪團看海發呆！福容各館四人同行價格超殺　墾丁美棧每人每晚只要500元
# 2020/03/05 15:48 英男「染新冠肺炎重症」　靠威士忌＋蜂蜜痊癒…憶染病過程：全身像被火車輾爆
# 2020/03/05 15:47 悲慘世界！女移工4年被扣薪82萬還要幫運毒…警救出她哭斷腸
# 2020/03/05 15:46 BTS防彈少年團首波FILA單品上市　慶祝「七個人的第七年」
# 2020/03/05 15:46 還沒做就先「夾娃娃」阿宅好心動！　漂亮女公關嬌喊買包包…只是一場春夢
# 2020/03/05 15:46 一個礦工之子 如何翻身金字塔頂端的房仲王？
# 2020/03/05 15:45 節省考生住宿交通費！金門大學成立「遠距視訊中心」進行線上面試
# ...

# %% [markdown]
# ### ② 如果想要依照類別分類，怎麼儲存會比較好？

# %%
'''
Your Code
'''
news = {}
news_list = []
for d in soup.find(class_="part_list_2").find_all('h3'):
    #print(d.find(class_="date").text, d.find_all('em')[0].text, d.find_all('a')[-1].text)
    news_class.append(d.find_all('em')[0].text)
    
    news['title'] = d.find(target="_blank").text
    news['date'] = d.find(class_="date").text
    news['class'] = d.find_all('em')[0].text
    news_list.append(news)
    news = {}
    
#print(news_class)
print(news_list)
# Out:
# [{'title': '死忠基迷如願加盟洋基\u3000他養的狗就叫「基特」', 'date': '2020/03/05 16:01', 'class': '體育'}, {'title': '手機品牌保持大比拚！iPhone海放Android旗艦機', 'date': '2020/03/05 16:01', 'class': '3C家電'}, {'title': '新北未取消酒測\u3000以「目視、酒味」判斷為主', 'date': '2020/03/05 16:00', 'class': '政治'}, {'title': '控法官「男盜女娼」收賄美金40萬元\u3000老營造商返台「我要面對」結果被起訴', 'date': '2020/03/05 15:59', 'class': '社會'}, {'title': '高虹安用大數據找出缺口罩地點\u3000陳時中：教教我們', 'date': '2020/03/05 15:57', 'class': '政治'}, {'title': '原來這些星座是另一半最想留住的幸運！包容力超高的情人TOP 4別輕易放手', 'date': '2020/03/05 15:57', 'class': '生活'}, {'title': '「疫」起迎轉機', 'date': '2020/03/05 15:55', 'class': '財經'}, {'title': '怎麼有效學習拿高分？專家給解答：讀書如同記住「遊戲規則」', 'date': '2020/03/05 15:55', 'class': '生活'}, {'title': '整理櫃子卻翻到「土豪級口罩」！她嗨喊「這大概100萬吧」…網笑：一夜致富', 'date': '2020/03/05 15:54', 'class': '網搜'}, {'title': '高速公路攔車抓人！改槍工廠曝光\u3000主嫌找車工鑽槍管販售', 'date': '2020/03/05 15:52', 'class': '社會'}, {'title': '王鴻薇批游錫堃「高調耍官威」\u3000要求向警察道歉', 'date': '2020/03/05 15:51', 'class': '政治'}, {'title': '首入選全球最佳新興智庫\u3000國防院：澎湖軍事戰略地位已超金馬'
# ...

# %% [markdown]
# ### ③ 哪一個類別的文章最多

# %%
'''
Your Code
'''
for news in news_list:
    print(news['class'])
    #for class in news['class']:
    #    print(class)
    #   #for k, v in news.items():
        #    print(k, v)
# Out:
# 體育
# 3C家電
# 政治
# 社會
# 政治
# 生活
# 財經
# 生活
# 網搜
# 社會
# 政治
# 軍武
# 法律
# 軍武
# 旅遊
# 國際
# 社會
# 體育
# 社會
# 財經
# 地方
# 財經
# 政治
# 國際
# 社會
# 大陸
# 體育
# 地方
# 社會
# 國際
# 寵物動物
# 國際
# 影劇
# 體育
# 政治
# 社會
# 論壇
# 大陸
# 財經
# 財經
# 大陸
# 健康
# 國際
# 財經
# 時尚
# 3C家電
# 財經
# 財經
# 財經
# 生活
# 政治
# 大陸
# 政治
# 政治
# 社會
# 政治
# 體育
# 財經
# 生活
# 生活
# 旅遊
# 社會
# 影劇
# ET車雲
# 財經
# 探索
# 國際
# 大陸
# 政治
# 社會
# 體育
# 政治
# 影劇
# 社會
# 寵物動物
# 生活
# 論壇
# 生活
# 地方
# 大陸
# 影劇
# ET車雲
# 3C家電
# 生活
# 寵物動物
# 影劇
# 旅遊
# 健康
# 3C家電
# 政治
# 3C家電
# 社會
# 大陸
# 生活
# 財經
# 社會
# 社會
# 財經
# 財經
# 影劇
