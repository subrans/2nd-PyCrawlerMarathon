# %% [markdown]
# # 反爬：代理伺服器/IP
#
# * 了解「IP 黑/白名單」的反爬蟲機制
# * 「IP 黑/白名單」反爬蟲的因應策略

# %% [markdown]
# ## 作業目標
#
# * 目前程式中的 proxy_ips 是手動輸入的，請根據 https://free-proxy-list.net/ 寫一個可自動化抓取可用 Proxy 的 proxy_ips。

# %%
import requests
from bs4 import BeautifulSoup
import re
import random

proxy_ips = []

'''
Your Code
'''
proxy_url = 'https://free-proxy-list.net/'
r = requests.get(proxy_url)
soup = BeautifulSoup(r.text, 'lxml')
soup.title 

trs = soup.find('table', attrs={'class':'table'}).find_all('tr')
for tr in trs:
    tds = tr.find_all('td')
    rows = []
    for td in tds:
        if td.text != '':
            rows.append(td.text)
    fields = {'IP Address':'', 
              'Port':'' , 
              'Code':'' ,
              'Anonymity':'', 
              'Google':'', 
              'Https':'', 
              'Last Checked':''}
    if len(rows) == 8:
        i=0
        for k in fields.keys():
            fields[k] = rows[i]
            proxy_ips.append(fields['IP Address'] + ':' + fields['Port'])
            i+=1
print(len(proxy_ips), proxy_ips)
# Out:
# 2100 ['103.140.24.21:', '103.140.24.21:45719', '103.140.24.21:45719', '103.140.24.21:45719', '103.140.24.21:45719', '103.140.24.21:45719', '103.140.24.21:45719', '85.10.219.103:', '85.10.219.103:1080', '85.10.219.103:1080', '85.10.219.103:1080', '85.10.219.103:1080', '85.10.219.103:1080', '85.10.219.103:1080', '118.175.207.205:', '118.175.207.205:61293', '118.175.207.205:61293', '118.175.207.205:61293', '118.175.207.205:61293', '118.175.207.205:61293', '118.175.207.205:61293', '45.161.202.2:', '45.161.202.2:3128', '45.161.202.2:3128', '45.161.202.2:3128', '45.161.202.2:3128', '45.161.202.2:3128', '45.161.202.2:3128', '103.242.44.80:', '103.242.44.80:8080', '103.242.44.80:8080', '103.242.44.80:8080', '103.242.44.80:8080', '103.242.44.80:8080', '103.242.44.80:8080', '45.33.90.184:', '45.33.90.184:8080', '45.33.90.184:8080', '45.33.90.184:8080', '45.33.90.184:8080', '45.33.90.184:8080', '45.33.90.184:8080', '85.10.219.101:', '85.10.219.101:1080', '85.10.219.101:1080', '85.10.219.101:1080', '85.10.219.101:1080', '85.10.219.101:1080', '85.10.219.101:1080', '179.108.169.71:', '179.108.169.71:8080', '179.108.169.71:8080', '179.108.169.71:8080', '179.108.169.71:8080', '179.108.169.71:8080', '179.108.169.71:8080', '95.179.185.213:', '95.179.185.213:3128', '95.179.185.213:3128', '95.179.185.213:3128', '95.179.185.213:3128', '95.179.185.213:3128', '95.179.185.213:3128', '119.47.91.243:', '119.47.91.243:8080', '119.47.91.243:8080', '119.47.91.243:8080', '119.47.91.243:8080', '119.47.91.243:8080', '119.47.91.243:8080', '103.235.199.46:', '103.235.199.46:31611', '103.235.199.46:31611', '103.235.199.46:31611', '103.235.199.46:31611', '103.235.199.46:31611', '103.235.199.46:31611', '95.179.197.59:', '95.179.197.59:8080', '95.179.197.59:8080', '95.179.197.59:8080', '95.179.197.59:8080', '95.179.197.59:8080', '95.179.197.59:8080', '187.87.38.28:', '187.87.38.28:53281', '187.87.38.28:53281', '187.87.38.28:53281', '187.87.38.28:53281', '187.87.38.28:53281', '187.87.38.28:53281', '154.126.211.169:', '154.126.211.169:41014', '154.126.211.169:41014', '154.126.211.169:41014', '154.126.211.169:41014', '154.126.211.169:41014', '154.126.211.169:41014', '190.214.45.18:', '190.214.45.18:50061', '190.214.45.18:50061', '190.214.45.18:50061', '190.214.45.18:50061', '190.214.45.18:50061', '190.214.45.18:50061', '191.37.183.209:', '191.37.183.209:60139', '191.37.183.209:60139', '191.37.183.209:60139', '191.37.183.209:60139', '191.37.183.209:60139', '191.37.183.209:60139', '202.165.47.26:', '202.165.47.26:8080', '202.165.47.26:8080', '202.165.47.26:8080', '202.165.47.26:8080', '202.165.47.26:8080', '202.165.47.26:8080', '206.189.36.13:', '206.189.36.13:47503', '206.189.36.13:47503', '206.189.36.13:47503', '206.189.36.13:47503', '206.189.36.13:47503', '206.189.36.13:47503', '191.98.184.123:', '191.98.184.123:42221', '191.98.184.123:42221', '191.98.184.123:42221', '191.98.184.123:42221', '191.98.184.123:42221', '191.98.184.123:42221', '179.184.230.194:', '179.184.230.194:46365', '179.184.230.194:46365', '179.184.230.194:46365', '179.184.230.194:46365', '179.184.230.194:46365', '179.184.230.194:46365', '190.11.15.14:', '190.11.15.14:55443', '190.11.15.14:55443', '190.11.15.14:55443', '190.11.15.14:55443', '190.11.15.14:55443', '190.11.15.14:55443', '200.73.128.5:', '200.73.128.5:8080', '200.73.128.5:8080', '200.73.128.5:8080', '200.73.128.5:8080', '200.73.128.5:8080', '200.73.128.5:8080', '41.190.95.20:', '41.190.95.20:56167', '41.190.95.20:56167', '41.190.95.20:56167', '41.190.95.20:56167', '41.190.95.20:56167', '41.190.95.20:56167', '75.80.242.9:', '75.80.242.9:41007', '75.80.242.9:41007', '75.80.242.9:41007', '75.80.242.9:41007', '75.80.242.9:41007', '75.80.242.9:41007', '81.95.230.211:', '81.95.230.211:3128', '81.95.230.211:3128', '81.95.230.211:3128', '81.95.230.211:3128', '81.95.230.211:3128', '81.95.230.211:3128', '124.41.211.188:', '124.41.211.188:39249', '124.41.211.188:39249', '124.41.211.188:39249', '124.41.211.188:39249', '124.41.211.188:39249', '124.4 ...

# %%
#for i in range(len(proxy_ips)):
for i in range(100):
    ip = random.choice(proxy_ips)
    print('Use', ip)
    try:
        resp = requests.get('http://ip.filefab.com/index.php',
                        proxies={'http': ip, 'https': ip}, timeout=10)
        soup = BeautifulSoup(resp.text, 'html5lib')
        print(soup.find('h1', id='ipd').text.strip())
    except:
        print('Fail')
# Out:
# Use 87.250.218.12:
# Fail
# Use 138.197.145.103:8080
# Fail
# Use 87.251.156.50:
# Fail
# Use 78.38.116.140:8080
# Fail
# Use 103.242.44.80:8080
# Fail
# Use 200.73.128.5:8080
# Fail
# Use 178.47.139.151:52230
# Fail
# Use 187.87.38.28:53281
# Fail
# Use 138.197.157.44:
# Fail
# Use 138.68.165.154:3128
# Fail
# Use 151.232.72.16:80
# Fail
# Use 87.250.218.12:33759
# Fail
# Use 35.220.131.188:80
# Fail
# Use 191.98.184.123:42221
# Fail
# Use 95.179.185.213:3128
# Fail
# Use 85.62.10.83:8080
# Fail
# Use 181.117.176.236:61358
# Fail
# Use 103.240.206.152:
# Fail
# Use 80.28.102.26:
# Fail
# Use 41.210.161.114:80
# Fail
# Use 110.74.199.68:38805
# Fail
# Use 112.78.187.186:50359
# Fail
# Use 203.154.111.150:45909
# Fail
# Use 36.81.255.22:8080
# Fail
# Use 178.151.156.112:34689
# Fail
# Use 109.234.39.153:8118
# Fail
# Use 176.121.48.48:49678
# Fail
# Use 95.179.185.213:3128
# Fail
# Use 5.160.72.149:55206
# Fail
# Use 78.38.116.140:8080
# Fail
# Use 36.66.218.121:35004
# Fail
# Use 191.37.183.209:60139
# Fail
# Use 103.83.99.69:3128
# Fail
# Use 198.199.120.102:3128
# Fail
# Use 24.172.225.122:53281
# Fail
# Use 41.66.75.109:8080
# Fail
# Use 203.202.248.35:80
# Fail
# Use 118.151.209.214:46327
# Fail
# Use 201.64.22.51:
# Fail
# Use 159.65.151.96:8080
# Fail
# Use 202.169.255.7:8181
# Fail
# Use 186.86.247.169:39168
# Fail
# Use 35.195.180.118:3128
# Fail
# Use 111.92.240.134:
# Fail
# Use 106.51.18.212:3128
# Fail
# Use 103.140.24.21:45719
